# %%
import numpy as np
import pandas as pd
import matplotlib as mlt

# %%
data = pd.read_csv('mushrooms.csv');
data = data.sample(frac=1)
data.head()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 5471     p         x           y         n       f    y               f
# 3110     p         x           f         g       f    c               f
# 2808     e         x           y         e       t    n               f
# 5171     p         f           s         b       t    f               f
# 7274     p         k           s         n       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 5471            c         n          b  ...                        s
# 3110            c         n          u  ...                        s
# 2808            c         b          n  ...                        s
# 5171            c         b          h  ...                        s
# 7274            c         n          b  ...                        k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
data.shape
# Out:
# (8124, 23)

# %%
splitrow = round(0.75 * data.shape[0])
datalatih = data.iloc[:splitrow,:]
datauji = data.iloc[splitrow:,:]

# %%
datalatih.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 4573     p         x           y         g       f    f               f
# 4731     p         f           y         g       f    f               f
# 7507     p         k           y         e       f    y               f
# 3035     e         f           y         n       t    n               f
# 1577     p         x           y         n       t    p               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 4573            c         b          g  ...                        k
# 4731            c         b          h  ...                        k
# 7507            c         n          b  ...                        s
# 3035            c         b          w  ...                        s
# 1577            c         n          p  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
datauji.head()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1264     e         x           f         n       t    n               f
# 1248     e         f           f         g       f    n               f
# 4557     e         x           y         u       f    n               f
# 1522     e         x           s         w       f    n               f
# 6654     p         f           s         e       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 1264            c         b          p  ...                        s
# 1248            w         b          n  ...                        s
# 4557            c         n          u  ...                        f
# 1522            w         b          k  ...                        s
# 6654            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
kolom = data.columns
for i in range(len(kolom)):
    print(f'{kolom[i]}->{data[kolom[i]].unique()}')
# Out:
# class->['p' 'e']
# cap-shape->['x' 'f' 'k' 'b' 's' 'c']
# cap-surface->['y' 'f' 's' 'g']
# cap-color->['n' 'g' 'e' 'b' 'y' 'w' 'p' 'u' 'c' 'r']
# bruises->['f' 't']
# odor->['y' 'c' 'n' 'f' 'a' 's' 'p' 'l' 'm']
# gill-attachment->['f' 'a']
# gill-spacing->['c' 'w']
# gill-size->['n' 'b']
# gill-color->['b' 'u' 'n' 'h' 'w' 'p' 'k' 'g' 'o' 'e' 'y' 'r']
# stalk-shape->['t' 'e']
# stalk-root->['?' 'b' 'c' 'e' 'r']
# stalk-surface-above-ring->['s' 'f' 'k' 'y']
# stalk-surface-below-ring->['s' 'k' 'f' 'y']
# stalk-color-above-ring->['p' 'w' 'g' 'n' 'o' 'b' 'e' 'c' 'y']
# stalk-color-below-ring->['w' 'g' 'p' 'o' 'n' 'b' 'e' 'c' 'y']
# veil-type->['p']
# veil-color->['w' 'o' 'n' 'y']
# ring-number->['o' 't' 'n']
# ring-type->['e' 'p' 'l' 'f' 'n']
# spore-print-color->['w' 'k' 'n' 'h' 'u' 'o' 'r' 'b' 'y']
# population->['v' 'y' 's' 'n' 'a' 'c']
# habitat->['l' 'd' 'g' 'p' 'u' 'm' 'w']

# %%
data.isnull().sum() #cek data ada yg gak terisi
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
kelas = pd.crosstab(index = datalatih['class'],columns="count")
probabilityKelas = kelas/kelas.sum()
probabilityKelas
# Out:
# col_0     count
# class
# e      0.515181
# p      0.484819

# %%
a = pd.crosstab(datalatih["cap-shape"],datalatih["class"]) #lihat bentul data 
a=a+1#laplace correction
a
# Out:
# class         e     p
# cap-shape
# b           300    40
# c             1     4
# f          1217  1156
# k           176   457
# s            26     1
# x          1425  1302

# %%
matrixproball = {}
for i in range(1,len(kolom)):
    crosstab = pd.crosstab(datalatih[kolom[i]],datalatih['class'])
    crosstab = crosstab+1;
    for a in range(crosstab.shape[1]):
        crosstab.iloc[:,a] = crosstab.iloc[:,a]/crosstab.iloc[:,a].sum()
    matrixproball[kolom[i]]=crosstab

# %%
matrixproball['cap-shape']
# Out:
# class             e         p
# cap-shape
# b          0.095390  0.013514
# c          0.000318  0.001351
# f          0.386963  0.390541
# k          0.055962  0.154392
# s          0.008267  0.000338
# x          0.453100  0.439865

# %%
datalatih.head()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 5471     p         x           y         n       f    y               f
# 3110     p         x           f         g       f    c               f
# 2808     e         x           y         e       t    n               f
# 5171     p         f           s         b       t    f               f
# 7274     p         k           s         n       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 5471            c         n          b  ...                        s
# 3110            c         n          u  ...                        s
# 2808            c         b          n  ...                        s
# 5171            c         b          h  ...                        s
# 7274            c         n          b  ...                        k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
datauji['cap-shape'].iloc[0]
# Out:
# 'x'

# %%
classe = probabilityKelas['count']['e'];
classp = probabilityKelas['count']['p'];
matrixproball[datauji.columns[1]]['e'][datauji[datauji.columns[1]].iloc[0]]
# Out:
# 0.45310015898251194

# %%
y_predict = [];
for i in range(datauji.shape[0]):
    classe = probabilityKelas['count']['e'];
    classp = probabilityKelas['count']['p'];
    for j in range(1,len(datauji.columns)):
        classe = classe*matrixproball[datauji.columns[j]]['e'][datauji[datauji.columns[j]].iloc[i]]
        classp = classp*matrixproball[datauji.columns[j]]['p'][datauji[datauji.columns[j]].iloc[i]]
        #print(datatest.columns[j])
        #print(datatest[datatest.columns[j]].iloc[i])
        #print(matrixproball[datatest.columns[j]]['e'][datatest[datatest.columns[j]].iloc[0]])
        #print(matrixproball[datatest.columns[j]]['p'][datatest[datatest.columns[j]].iloc[0]])
    if(classe>classp):
        y_predict.append('e')
    else:
        y_predict.append('p')

# %%
y_actual = datauji['class'].tolist()

# %%
hasil = {'y_predict':y_predict,
         'y_actual' :y_actual}

# %%
hsl = pd.DataFrame(hasil,columns=['y_actual','y_predict'])

# %%
confmat = pd.crosstab(hsl['y_actual'],hsl['y_predict'],rownames=['actual'],colnames=['predict'])
confmat
# Out:
# predict     e    p
# actual
# e        1061    8
# p          77  885

# %%
datauji[datauji['class']=='e']['class'].count()
# Out:
# 1069

# %%
recalle = (confmat['e']['e']/confmat.iloc[0].sum())*100
recallp = confmat['p']['p']/confmat.iloc[1].sum()*100
prece = confmat['e']['e']/confmat.iloc[:,0].sum()*100
precp = confmat['p']['p']/confmat.iloc[:,1].sum()*100

# %%
print("recall E")
recalle
# Out:
# recall E
# 99.25163704396633

# %%
print("recall p")
recallp
# Out:
# recall p
# 91.995841995842

# %%
print("precision e")
prece
# Out:
# precision e
# 93.23374340949033

# %%
print("precision p")
precp
# Out:
# precision p
# 99.10414333706606
